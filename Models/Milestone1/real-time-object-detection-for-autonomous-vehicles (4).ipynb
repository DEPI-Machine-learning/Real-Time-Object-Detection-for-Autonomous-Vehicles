# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))

# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
ls /kaggle/input/*/
# Out:
# data_object_calib/    data_object_image_3/
# data_object_image_2/  data_object_label_2/

# %% [markdown]
# # Libraries

# %%
import os
from collections import Counter
import matplotlib.pyplot as plt
import cv2
import seaborn as sns
import numpy as np

# %%
labels_dir = "/kaggle/input/kitti-dataset/data_object_label_2/training/label_2/"
image_dir = "/kaggle/input/kitti-dataset/data_object_image_2/training/image_2/"

# %% [markdown]
# # Read Image

# %%
def read_image(image_name):
    image_path = os.path.join(image_dir, f"{image_name}.png") 
    image = cv2.imread(image_path)

    if image is None:
        raise FileNotFoundError(f"Not Found: {image_path}")

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    print(f"Image shape: {image.shape}")
    return image

# %%
image = read_image("000002")
plt.imshow(image)
plt.axis("off")
plt.show()
# Out:
# Image shape: (375, 1242, 3)

# %% [markdown]
# # Data Exploration

# %% [markdown]
# Count the occurrences of each object class in the KITTI dataset labels and visualize the distribution using a bar chart.

# %%
def label_counts_distribution():
    label_counts = Counter()
    for label_file in os.listdir(labels_dir):
        with open(os.path.join(labels_dir, label_file), "r") as file:
            for line in file:
                class_name = line.split()[0] 
                label_counts[class_name] += 1 
    return label_counts

# %%
label_counts = label_counts_distribution()

print("Distribution")
for label, count in label_counts.items():
    print(f"{label}: {count}")

plt.figure(figsize=(8, 5))
plt.bar(label_counts.keys(), label_counts.values(), color='blue')
plt.xlabel("Objects")
plt.ylabel("Number of repetitions")
plt.title("Distribution")
plt.xticks(rotation=45)
plt.show()
# Out:
# Distribution
# Car: 28742
# Van: 2914
# DontCare: 11295
# Misc: 973
# Cyclist: 1627
# Pedestrian: 4487
# Truck: 1094
# Tram: 511
# Person_sitting: 222

# %% [markdown]
# ## Data Quality Analysis

# %% [markdown]
# ### Image Resolution

# %%
def image_resolutions():
    resolutions = []
    for image_file in os.listdir(image_dir):
        image_path = os.path.join(image_dir, image_file)
        img = cv2.imread(image_path)
    
        if img is not None:
            resolutions.append(img.shape[:2])
    return np.array(resolutions)

# %%
resolutions = image_resolutions()
unique_resolutions = np.unique(resolutions, axis=0)
print("Unique Image Resolutions:", unique_resolutions)
# Out:
# Unique Image Resolutions: [[ 370 1224]
#  [ 374 1238]
#  [ 375 1242]
#  [ 376 1241]]

# %% [markdown]
# ### Bounding Box

# %% [markdown]
# This method reads a label file, extracts bounding box coordinates for detected objects, and retrieves environmental tags (e.g., weather, lighting) along with the road type. It returns a list of bounding boxes, environment tags, and the road type.

# %%
def extract_bounding_boxes_and_tags(imageName):
    bounding_boxes = [] 
    environment_tags = []
    road_type = ""
    label_path = f"{labels_dir}{imageName}.txt"
    if os.path.exists(label_path):
        with open(label_path, "r") as file:
            for line in file:
                values = line.split()
                if values[0] != 'DontCare':
                    x_min, y_min, x_max, y_max = map(float, values[4:8])
                    bounding_boxes.append((x_min, y_min, x_max, y_max))
                    environment_tags = values[-4:-1] 
                    road_type = values[-1] 
    else:
        print(f"Not Found: {label_path}")

    return bounding_boxes, environment_tags, road_type

# %%
imageName = "000007"
img = read_image(imageName)

bounding_boxes, environment_tags, road_type = extract_bounding_boxes_and_tags(imageName)

environment_info = ", ".join(environment_tags) if environment_tags else "N/A"
title_text = f"Sample Image with Bounding Boxes\nTags: {environment_info}, Road Type: {road_type}"


plt.figure(figsize=(10, 6))
plt.imshow(img)
plt.axis("off")
plt.title(title_text)


for bbox in bounding_boxes:
    print(bbox)
    x_min, y_min, x_max, y_max = bbox
    plt.plot([x_min, x_max, x_max, x_min, x_min], [y_min, y_min, y_max, y_max, y_min], color='red')

plt.show()
# Out:
# Image shape: (375, 1242, 3)
# (564.62, 174.59, 616.43, 224.74)
# (481.59, 180.09, 512.55, 202.42)
# (542.05, 175.55, 565.27, 193.79)
# (330.6, 176.09, 355.61, 213.6)

# %% [markdown]
# ### Detect Biases

# %% [markdown]
# function extracts the center coordinates (x_center, y_center) of bounding boxes from label files in labels_dir, grouping them by object class in a dictionary.
# It returns a dictionary where keys are object classes and values are lists of center positions.

# %%
# def detect_box_positions():
#     bbox_positions = {}
#     for label_file in os.listdir(labels_dir):
#         with open(os.path.join(labels_dir, label_file), "r") as file:
#             for line in file:
#                 parts = line.split()
#                 class_id = parts[0]  
#                 x_center, y_center = map(float, parts[1:3])  

#                 if class_id != "DontCare":
#                     if class_id not in bbox_positions:
#                         bbox_positions[class_id] = []
                
#                     bbox_positions[class_id].append((x_center, y_center))
#     return bbox_positions

# %%
# bbox_positions = detect_box_positions()
# plt.figure(figsize=(10, 6))

# colors = ['red', 'blue', 'green', 'purple', 'orange']
# for i, (class_id, positions) in enumerate(bbox_positions.items()):
#     positions = np.array(positions)
#     plt.scatter(positions[:, 0], positions[:, 1], alpha=0.5, s=10, color=colors[i % len(colors)], label=f"Class {class_id}")

# plt.xlabel("X Center")
# plt.ylabel("Y Center")
# plt.title("Bounding Boxes")
# plt.gca().invert_yaxis()
# plt.legend()
# plt.show()

# %%
# if not (0 <= x_center <= 1) or not (0 <= y_center <= 1):
#     print(f"Warning: Invalid coordinates ({x_center}, {y_center}) in file {label_file}")

# %%
# bbox_positions = [pos for pos in bbox_positions if 0 <= pos[0] <= 1 and 0 <= pos[1] <= 1]
# bbox_positions

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

labels_dir = "/kaggle/input/kitti-dataset/data_object_label_2/training/label_2/"

def detect_box_positions():
    bbox_positions = {}
    for label_file in os.listdir(labels_dir):
        with open(os.path.join(labels_dir, label_file), "r") as file:
            for line in file:
                parts = line.split()
                class_id = parts[0]  
                x_min, y_min, x_max, y_max = map(float, parts[4:8])  

                x_center = (x_min + x_max) / 2
                y_center = (y_min + y_max) / 2

                if class_id != "DontCare":
                    if class_id not in bbox_positions:
                        bbox_positions[class_id] = []
                
                    bbox_positions[class_id].append((x_center, y_center))
    return bbox_positions

bbox_positions = detect_box_positions()

plt.figure(figsize=(10, 6))
colors = ['red', 'blue', 'green', 'purple', 'orange']

for i, (class_id, positions) in enumerate(bbox_positions.items()):
    positions = np.array(positions)
    plt.scatter(positions[:, 0], positions[:, 1], alpha=0.5, s=10, color=colors[i % len(colors)], label=f"Class {class_id}")

plt.xlabel("X Center")
plt.ylabel("Y Center")
plt.title("Distribution of Object Centers")
plt.gca().invert_yaxis()
plt.legend()
plt.show()

# %% [markdown]
# **Resizes** images to **416×416** using the **Letterbox** technique while maintaining aspect ratio. Adjusts **Bounding Box (BBox) coordinates** to account for scaling and padding effects. The updated images and modified annotation files are saved in the specified output directory.

# %%
# !pip install ultralytics

# %%
# import os
# from ultralytics.utils.ops import letterbox
# import cv2

# # Function to adjust the Bounding Box based on scale and padding
# def adjust_bbox(bbox, scale, pad):
#     pad_left, pad_top = pad
#     x_min_new = int(bbox[0] * scale + pad_left)
#     y_min_new = int(bbox[1] * scale + pad_top)
#     x_max_new = int(bbox[2] * scale + pad_left)
#     y_max_new = int(bbox[3] * scale + pad_top)
#     return [x_min_new, y_min_new, x_max_new, y_max_new]

# # Input image directory for KITTI
# input_dir = "path/to/kitti/images"  # Example: "dataset/KITTI/images"
# # Output directory to save resized images
# output_dir = "path/to/output/images"  # Example: "dataset/KITTI/resized_images"
# # Labels directory for KITTI dataset
# labels_dir = "path/to/kitti/labels"  # Example: "dataset/KITTI/labels"

# # Create output directory if it doesn't exist
# if not os.path.exists(output_dir):
#     os.makedirs(output_dir)

# # Loop through all the files in the image directory
# for img_name in os.listdir(input_dir):
#     # Check if the file is an image (jpg or png)
#     if img_name.lower().endswith(('.jpg', '.jpeg', '.png')):
#         img_path = os.path.join(input_dir, img_name)
#         image = cv2.imread(img_path)
        
#         # Ensure the image is read correctly
#         if image is None:
#             print(f"Unable to read image: {img_path}")
#             continue
        
#         # Apply Letterbox technique to resize the image to 416×416
#         resized_image, ratio, (dw, dh) = letterbox(image, new_shape=(416, 416), auto=True)
        
#         # Save the resized image
#         out_path = os.path.join(output_dir, img_name)
#         cv2.imwrite(out_path, resized_image)
#         print(f"Processed image: {img_name}")
        
#         # Update the labels
#         label_file_path = os.path.join(labels_dir, img_name.replace(".jpg", ".txt").replace(".jpeg", ".txt"))
        
#         if os.path.exists(label_file_path):
#             with open(label_file_path, 'r') as f:
#                 lines = f.readlines()

#             # Modify each bounding box in the label file
#             updated_labels = []
#             for line in lines:
#                 label_info = line.strip().split()
#                 bbox = list(map(float, label_info[4:]))  # Get the bbox coordinates [x_min, y_min, x_max, y_max]
                
#                 # Adjust the bbox based on scale and padding
#                 updated_bbox = adjust_bbox(bbox, ratio, (dw, dh))
                
#                 # Reassemble the label with the updated bbox
#                 updated_line = f"{label_info[0]} " + " ".join(map(str, updated_bbox)) + "\n"
#                 updated_labels.append(updated_line)

#             # Save the updated labels
#             with open(label_file_path, 'w') as f:
#                 f.writelines(updated_labels)
#                 print(f"Updated labels for image: {img_name}")

# %% [markdown]
# This is the same code

# %%
import os
import cv2

# Function to adjust the bounding box based on separate scale factors for width and height
def adjust_bbox(bbox, scale_x, scale_y):
    x_min_new = int(bbox[0] * scale_x)
    y_min_new = int(bbox[1] * scale_y)
    x_max_new = int(bbox[2] * scale_x)
    y_max_new = int(bbox[3] * scale_y)
    return [x_min_new, y_min_new, x_max_new, y_max_new]

# Input image directory for KITTI
input_dir = "/kaggle/input/kitti-dataset/data_object_image_2/training/image_2/"  # Example: "dataset/KITTI/images"
# Output directory to save resized images
output_dir = "/kaggle/working/resized_images"  # Example: "dataset/KITTI/resized_images"
# Labels directory for the KITTI dataset
labels_dir = "/kaggle/working/updated_labels"  # Example: "dataset/KITTI/labels"

# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Loop through all the files in the image directory
for img_name in os.listdir(input_dir):
    # Check if the file is an image (jpg, jpeg, or png)
    if img_name.lower().endswith(('.jpg', '.jpeg', '.png')):
        img_path = os.path.join(input_dir, img_name)
        image = cv2.imread(img_path)
        
        # Ensure the image is read correctly
        if image is None:
            print(f"Unable to read image: {img_path}")
            continue
        
        # Get original image dimensions
        orig_h, orig_w = image.shape[:2]
        # Define new dimensions (width, height)
        new_w, new_h = 416, 416
        
        # Calculate scaling factors for width and height
        scale_x = new_w / orig_w
        scale_y = new_h / orig_h
        
        # Resize the image using cv2.resize
        resized_image = cv2.resize(image, (new_w, new_h))
        
        # Save the resized image
        out_path = os.path.join(output_dir, img_name)
        cv2.imwrite(out_path, resized_image)
        print(f"Processed image: {img_name}")
        
        # Update the labels
        # Update file extension for images (handles jpg, jpeg, and png)
        label_file_path = os.path.join(labels_dir, img_name.replace(".jpg", ".txt")
                                                        .replace(".jpeg", ".txt")
                                                        .replace(".png", ".txt"))
        
        if os.path.exists(label_file_path):
            with open(label_file_path, 'r') as f:
                lines = f.readlines()

            updated_labels = []
            for line in lines:
                label_info = line.strip().split()
                # Extract the bounding box coordinates: [x_min, y_min, x_max, y_max]
                bbox = list(map(float, label_info[4:8]))
                
                # Adjust the bounding box coordinates based on scaling factors
                updated_bbox = adjust_bbox(bbox, scale_x, scale_y)
                
                # Reassemble the line with the updated bounding box coordinates
                updated_line = f"{label_info[0]} " + " ".join(map(str, updated_bbox)) + "\n"
                updated_labels.append(updated_line)

            # Save the updated labels
            with open(label_file_path, 'w') as f:
                f.writelines(updated_labels)
                print(f"Updated labels for image: {img_name}")
# Out:
# Processed image: 005084.png
# Processed image: 003065.png
# Processed image: 003741.png
# Processed image: 004725.png
# Processed image: 001183.png
# Processed image: 005660.png
# Processed image: 007355.png
# Processed image: 003244.png
# Processed image: 002594.png
# Processed image: 001703.png
# Processed image: 003380.png
# Processed image: 007190.png
# Processed image: 004566.png
# Processed image: 002584.png
# Processed image: 004035.png
# Processed image: 001840.png
# Processed image: 005647.png
# Processed image: 004924.png
# Processed image: 005000.png
# Processed image: 007456.png
# Processed image: 006796.png
# Processed image: 000419.png
# Processed image: 002712.png
# Processed image: 006386.png
# Processed image: 000920.png
# Processed image: 000585.png
# Processed image: 001593.png
# Processed image: 004178.png
# Processed image: 002011.png
# Processed image: 007203.png
# Processed image: 004710.png
# Processed image: 002312.png
# Processed image: 003141.png
# Processed image: 003053.png
# Processed image: 006833.png
# Processed image: 004278.png
# Processed image: 005398.png
# Processed image: 000313.png
# Processed image: 002084.png
# Processed image: 000603.png
# Processed image: 007284.png
# Processed image: 001669.png
# Processed image: 004656.png
# Processed image: 007141.png
# Processed image: 005328.png
# Processed image: 003381.png
# Processed image: 004772.png
# Processed image: 005847.png
# Processed image: 005504.png
# Processed image: 005092.png
# Processed image: 000224.png
# Processed image: 002735.png
# Processed image: 000121.png
# Processed image: 000598.png
# Processed image: 006027.png
# Processed image: 005001.png
# Processed image: 001249.png
# Processed image: 005699.png
# Processed image: 002604.png
# Processed image: 000370.png
# Processed image: 004779.png
# Processed image: 003658.png
# Processed image: 002257.png
# Processed image: 002454.png
# Processed image: 002050.png
# Processed image: 002665.png
# Processed image: 004618.png
# Processed image: 005374.png
# Processed image: 003679.png
# Processed image: 004402.png
# Processed image: 001537.png
# Processed image: 006662.png
# Processed image: 004191.png
# Processed image: 002572.png
# Processed image: 001118.png
# Processed image: 005622.png
# Processed image: 005954.png
# Processed image: 004317.png
# Processed image: 002014.png
# Processed image: 000514.png
# Processed image: 000750.png
# Processed image: 006472.png
# Processed image: 003749.png
# Processed image: 003334.png
# Processed image: 005544.png
# Processed image: 007029.png
# Processed image: 005911.png
# Processed image: 004590.png
# Processed image: 006625.png
# Processed image: 000546.png
# Processed image: 003025.png
# Processed image: 001923.png
# Processed image: 001143.png
# Processed image: 000837.png
# Processed image: 006080.png
# Processed image: 004378.png
# Processed image: 006333.png
# Processed image: 006664.png
# Processed image: 000505.png
# Processed image: 005974.png
# Processed image: 006844.png
# Processed image: 000572.png
# Processed image: 003403.png
# Processed image: 003918.png
# Processed image: 006568.png
# Processed image: 006397.png
# Processed image: 007415.png
# Processed image: 006214.png
# Processed image: 002503.png
# Processed image: 001566.png
# Processed image: 001661.png
# Processed image: 002087.png
# Processed image: 006992.png
# Processed image: 007145.png
# Processed image: 001910.png
# Processed image: 004706.png
# Processed image: 002530.png
# Processed image: 003566.png
# Processed image: 001680.png
# Processed image: 002073.png
# Processed image: 004796.png
# Processed image: 001493.png
# Processed image: 002513.png
# Processed image: 000189.png
# Processed image: 003395.png
# Processed image: 000395.png
# Processed image: 006924.png
# Processed image: 002547.png
# Processed image: 001462.png
# Processed image: 005342.png
# Processed image: 000039.png
# Processed image: 000339.png
# Processed image: 000243.png
# Processed image: 001572.png
# Processed image: 003035.png
# Processed image: 000444.png
# Processed image: 004113.png
# Processed image: 004185.png
# Processed image: 002396.png
# Processed image: 006884.png
# Processed image: 005501.png
# Processed image: 005446.png
# Processed image: 006697.png
# Processed image: 002362.png
# Processed image: 007171.png
# Processed image: 005780.png
# Processed image: 001191.png
# Processed image: 002602.png
# Processed image: 004812.png
# Processed image: 005345.png
# Processed image: 006279.png
# Processed image: 004312.png
# Processed image: 001329.png
# Processed image: 003793.png
# Processed image: 005846.png
# Processed image: 004977.png
# Processed image: 006584.png
# Processed image: 000696.png
# Processed image: 001164.png
# Processed image: 005595.png
# Processed image: 005189.png
# Processed image: 004729.png
# Processed image: 002345.png
# Processed image: 000805.png
# Processed image: 005935.png
# Processed image: 001619.png
# Processed image: 006263.png
# Processed image: 001106.png
# Processed image: 006606.png
# Processed image: 002678.png
# Processed image: 005397.png
# Processed image: 003880.png
# Processed image: 004243.png
# Processed image: 001828.png
# Processed image: 000491.png
# Processed image: 000085.png
# Processed image: 006867.png
# Processed image: 004241.png
# Processed image: 006137.png
# Processed image: 003411.png
# Processed image: 004303.png
# Processed image: 002766.png
# Processed image: 002523.png
# Processed image: 006485.png
# Processed image: 000646.png
# Processed image: 005074.png
# Processed image: 005646.png
# Processed image: 000938.png
# Processed image: 002273.png
# Processed image: 003856.png
# Processed image: 002072.png
# Processed image: 000461.png
# Processed image: 006307.png
# Processed image: 002175.png
# Processed image: 002982.png
# Processed image: 007409.png
# Processed image: 002070.png
# Processed image: 006950.png
# Processed image: 001414.png
# Processed image: 006821.png
# Processed image: 005795.png
# Processed image: 004127.png
# Processed image: 005716.png
# Processed image: 005490.png
# Processed image: 003293.png
# Processed image: 001791.png
# Processed image: 000178.png
# Processed image: 001476.png
# Processed image: 007237.png
# Processed image: 005321.png
# Processed image: 004733.png
# Processed image: 002814.png
# Processed image: 000748.png
# Processed image: 001032.png
# Processed image: 004999.png
# Processed image: 006352.png
# Processed image: 000689.png
# Processed image: 003029.png
# Processed image: 005710.png
# Processed image: 005007.png
# Processed image: 004201.png
# Processed image: 001694.png
# Processed image: 007166.png
# Processed image: 006661.png
# Processed image: 003491.png
# Processed image: 006592.png
# Processed image: 005773.png
# Processed image: 000808.png
# Processed image: 007239.png
# Processed image: 002688.png
# Processed image: 004609.png
# Processed image: 001450.png
# Processed image: 007207.png
# Processed image: 006601.png
# Processed image: 005463.png
# Processed image: 003266.png
# Processed image: 001421.png
# Processed image: 001300.png
# Processed image: 003050.png
# Processed image: 000436.png
# Processed image: 001762.png
# Processed image: 002291.png
# Processed image: 000972.png
# Processed image: 006110.png
# Processed image: 006459.png
# Processed image: 005438.png
# Processed image: 002692.png
# Processed image: 002638.png
# Processed image: 006724.png
# Processed image: 002071.png
# Processed image: 000715.png
# Processed image: 000345.png
# Processed image: 002621.png
# Processed image: 003009.png
# Processed image: 003161.png
# Processed image: 002171.png
# Processed image: 001616.png
# Processed image: 003275.png
# Processed image: 002770.png
# Processed image: 004541.png
# Processed image: 006366.png
# Processed image: 005375.png
# Processed image: 003585.png
# Processed image: 002135.png
# Processed image: 005071.png
# Processed image: 002200.png
# Processed image: 006705.png
# Processed image: 007003.png
# Processed image: 001257.png
# Processed image: 001381.png
# Processed image: 001647.png
# Processed image: 000367.png
# Processed image: 003314.png
# Processed image: 001820.png
# Processed image: 005908.png
# Processed image: 001427.png
# Processed image: 003233.png
# Processed image: 004302.png
# Processed image: 004111.png
# Processed image: 002915.png
# Processed image: 004673.png
# Processed image: 007043.png
# Processed image: 004443.png
# Processed image: 000647.png
# Processed image: 004672.png
# Processed image: 004947.png
# Processed image: 006468.png
# Processed image: 004466.png
# Processed image: 004385.png
# Processed image: 007076.png
# Processed image: 004484.png
# Processed image: 006672.png
# Processed image: 004983.png
# Processed image: 007402.png
# Processed image: 001848.png
# Processed image: 004538.png
# Processed image: 007341.png
# Processed image: 005650.png
# Processed image: 003169.png
# Processed image: 006166.png
# Processed image: 001091.png
# Processed image: 000216.png
# Processed image: 005089.png
# Processed image: 007280.png
# Processed image: 006031.png
# Processed image: 005636.png
# Processed image: 004044.png
# Processed image: 006989.png
# Processed image: 003756.png
# Processed image: 002775.png
# Processed image: 004646.png
# Processed image: 007337.png
# Processed image: 007384.png
# Processed image: 005711.png
# Processed image: 007365.png
# Processed image: 002937.png
# Processed image: 001618.png
# Processed image: 005053.png
# Processed image: 000120.png
# Processed image: 003544.png
# Processed image: 003019.png
# Processed image: 005437.png
# Processed image: 002869.png
# Processed image: 006819.png
# Processed image: 006288.png
# Processed image: 001928.png
# Processed image: 000545.png
# Processed image: 003121.png
# Processed image: 002437.png
# Processed image: 005783.png
# Processed image: 001083.png
# Processed image: 005542.png
# Processed image: 002299.png
# Processed image: 006463.png
# Processed image: 002192.png
# Processed image: 006928.png
# Processed image: 003146.png
# Processed image: 003104.png
# Processed image: 004304.png
# Processed image: 003105.png
# Processed image: 006305.png
# Processed image: 001160.png
# Processed image: 001938.png
# Processed image: 000575.png
# Processed image: 003550.png
# Processed image: 003345.png
# Processed image: 002199.png
# Processed image: 003602.png
# Processed image: 002089.png
# Processed image: 002357.png
# Processed image: 007381.png
# Processed image: 001399.png
# Processed image: 006423.png
# Processed image: 004153.png
# Processed image: 005410.png
# Processed image: 000426.png
# Processed image: 005033.png
# Processed image: 003907.png
# Processed image: 000752.png
# Processed image: 007176.png
# Processed image: 001725.png
# Processed image: 002723.png
# Processed image: 001029.png
# Processed image: 000787.png
# Processed image: 006822.png
# Processed image: 004682.png
# Processed image: 001081.png
# Processed image: 005961.png
# Processed image: 000859.png
# Processed image: 001350.png
# Processed image: 005998.png
# Processed image: 001242.png
# Processed image: 003447.png
# Processed image: 007393.png
# Processed image: 006835.png
# Processed image: 000953.png
# Processed image: 005919.png
# Processed image: 001261.png
# Processed image: 003807.png
# Processed image: 006865.png
# Processed image: 006082.png
# Processed image: 002023.png
# Processed image: 006516.png
# Processed image: 004923.png
# Processed image: 000229.png
# Processed image: 002719.png
# Processed image: 001583.png
# Processed image: 001059.png
# Processed image: 006180.png
# Processed image: 004835.png
# Processed image: 001074.png
# Processed image: 001739.png
# Processed image: 000082.png
# Processed image: 007242.png
# Processed image: 004503.png
# Processed image: 003634.png
# Processed image: 003366.png
# Processed image: 006444.png
# Processed image: 000467.png
# Processed image: 001123.png
# Processed image: 005729.png
# Processed image: 003574.png
# Processed image: 001251.png
# Processed image: 001137.png
# Processed image: 002917.png
# Processed image: 004247.png
# Processed image: 005522.png
# Processed image: 001298.png
# Processed image: 004147.png
# Processed image: 001772.png
# Processed image: 000914.png
# Processed image: 000834.png
# Processed image: 002726.png
# Processed image: 000632.png
# Processed image: 000630.png
# Processed image: 005448.png
# Processed image: 006243.png
# Processed image: 004285.png
# Processed image: 006842.png
# Processed image: 007077.png
# Processed image: 002113.png
# Processed image: 004330.png
# Processed image: 005405.png
# Processed image: 000247.png
# Processed image: 003760.png
# Processed image: 001184.png
# Processed image: 000535.png
# Processed image: 003018.png
# Processed image: 005860.png
# Processed image: 006023.png
# Processed image: 005638.png
# Processed image: 004559.png
# Processed image: 001185.png
# Processed image: 003729.png
# Processed image: 002862.png
# Processed image: 004816.png
# Processed image: 006230.png
# Processed image: 001245.png
# Processed image: 007153.png
# Processed image: 001373.png
# Processed image: 005366.png
# Processed image: 001079.png
# Processed image: 007342.png
# Processed image: 003194.png
# Processed image: 006518.png
# Processed image: 003354.png
# Processed image: 000794.png
# Processed image: 007042.png
# Processed image: 004604.png
# Processed image: 006760.png
# Processed image: 004582.png
# Processed image: 002215.png
# Processed image: 002539.png
# Processed image: 000483.png
# Processed image: 001174.png
# Processed image: 000618.png
# Processed image: 005900.png
# Processed image: 007172.png
# Processed image: 001996.png
# Processed image: 005195.png
# Processed image: 005867.png
# Processed image: 000263.png
# Processed image: 003316.png
# Processed image: 002794.png
# Processed image: 005063.png
# Processed image: 002872.png
# Processed image: 005308.png
# Processed image: 004987.png
# Processed image: 002076.png
# Processed image: 001020.png
# Processed image: 000145.png
# Processed image: 001135.png
# Processed image: 004021.png
# Processed image: 005433.png
# Processed image: 006435.png
# Processed image: 004173.png
# Processed image: 006289.png
# Processed image: 002847.png
# Processed image: 007236.png
# Processed image: 004611.png
# Processed image: 003120.png
# Processed image: 004635.png
# Processed image: 002152.png
# Processed image: 000344.png
# Processed image: 004521.png
# Processed image: 001813.png
# Processed image: 005179.png
# Processed image: 003397.png
# Processed image: 005752.png
# Processed image: 006142.png
# Processed image: 003157.png
# Processed image: 002773.png
# Processed image: 004955.png
# Processed image: 006370.png
# Processed image: 001225.png
# Processed image: 001941.png
# Processed image: 003994.png
# Processed image: 003929.png
# Processed image: 006218.png
# Processed image: 005920.png
# Processed image: 006546.png
# Processed image: 002697.png
# Processed image: 002886.png
# Processed image: 004401.png
# Processed image: 006988.png
# Processed image: 005461.png
# Processed image: 001989.png
# Processed image: 002772.png
# Processed image: 007099.png
# Processed image: 005251.png
# Processed image: 003457.png
# Processed image: 004356.png
# Processed image: 005576.png
# Processed image: 002168.png
# Processed image: 006527.png
# Processed image: 006634.png
# Processed image: 005505.png
# Processed image: 006816.png
# Processed image: 002458.png
# Processed image: 001997.png
# Processed image: 006323.png
# Processed image: 004266.png
# Processed image: 002143.png
# Processed image: 005541.png
# Processed image: 006450.png
# Processed image: 004507.png
# Processed image: 003097.png
# Processed image: 006326.png
# Processed image: 002271.png
# Processed image: 007413.png
# Processed image: 000048.png
# Processed image: 003704.png
# Processed image: 001891.png
# Processed image: 003143.png
# Processed image: 003375.png
# Processed image: 002708.png
# Processed image: 007311.png
# Processed image: 003632.png
# Processed image: 006059.png
# Processed image: 006012.png
# Processed image: 000778.png
# Processed image: 001321.png
# Processed image: 005878.png
# Processed image: 006343.png
# Processed image: 003946.png
# Processed image: 000671.png
# Processed image: 006111.png
# Processed image: 005443.png
# Processed image: 005720.png
# Processed image: 005077.png
# Processed image: 006751.png
# Processed image: 000198.png
# Processed image: 000149.png
# Processed image: 000990.png
# Processed image: 007297.png
# Processed image: 000007.png
# Processed image: 002825.png
# Processed image: 000163.png
# Processed image: 001227.png
# Processed image: 001665.png
# Processed image: 003082.png
# Processed image: 004963.png
# Processed image: 004909.png
# Processed image: 003228.png
# Processed image: 002822.png
# Processed image: 003183.png
# Processed image: 001080.png
# Processed image: 005555.png
# Processed image: 000961.png
# Processed image: 001435.png
# Processed image: 000142.png
# Processed image: 002475.png
# Processed image: 005184.png
# Processed image: 007211.png
# Processed image: 000784.png
# Processed image: 000046.png
# Processed image: 005014.png
# Processed image: 002933.png
# Processed image: 002241.png
# Processed image: 006379.png
# Processed image: 003241.png
# Processed image: 003706.png
# Processed image: 004095.png
# Processed image: 002769.png
# Processed image: 006024.png
# Processed image: 003289.png
# Processed image: 003547.png
# Processed image: 000609.png
# Processed image: 006471.png
# Processed image: 005885.png
# Processed image: 007131.png
# Processed image: 000564.png
# Processed image: 003036.png
# Processed image: 002526.png
# Processed image: 004793.png
# Processed image: 000349.png
# Processed image: 005651.png
# Processed image: 002482.png
# Processed image: 001741.png
# Processed image: 000277.png
# Processed image: 007264.png
# Processed image: 006410.png
# Processed image: 002278.png
# Processed image: 006363.png
# Processed image: 005035.png
# Processed image: 004526.png
# Processed image: 004864.png
# Processed image: 007031.png
# Processed image: 003771.png
# Processed image: 004074.png
# Processed image: 003645.png
# Processed image: 003502.png
# Processed image: 003022.png
# Processed image: 004100.png
# Processed image: 001763.png
# Processed image: 006097.png
# Processed image: 000660.png
# Processed image: 005358.png
# Processed image: 005359.png
# Processed image: 001330.png
# Processed image: 004122.png
# Processed image: 005503.png
# Processed image: 003782.png
# Processed image: 001927.png
# Processed image: 003963.png
# Processed image: 001469.png
# Processed image: 004685.png
# Processed image: 002850.png
# Processed image: 006360.png
# Processed image: 004944.png
# Processed image: 005866.png
# Processed image: 005996.png
# Processed image: 004841.png
# Processed image: 007288.png
# Processed image: 004349.png
# Processed image: 000489.png
# Processed image: 002888.png
# Processed image: 003879.png
# Processed image: 006378.png
# Processed image: 002644.png
# Processed image: 001609.png
# Processed image: 001745.png
# Processed image: 000236.png
# Processed image: 001863.png
# Processed image: 006076.png
# Processed image: 006425.png
# Processed image: 001293.png
# Processed image: 000118.png
# Processed image: 003373.png
# Processed image: 006115.png
# Processed image: 005045.png
# Processed image: 001019.png
# Processed image: 004625.png
# Processed image: 006104.png
# Processed image: 004791.png
# Processed image: 004290.png
# Processed image: 000996.png
# Processed image: 006470.png
# Processed image: 001995.png
# Processed image: 000607.png
# Processed image: 001517.png
# Processed image: 005156.png
# Processed image: 003968.png
# Processed image: 000712.png
# Processed image: 004874.png
# Processed image: 006316.png
# Processed image: 002725.png
# Processed image: 004953.png
# Processed image: 002268.png
# Processed image: 001023.png
# Processed image: 002361.png
# Processed image: 001206.png
# Processed image: 003386.png
# Processed image: 001284.png
# Processed image: 007163.png
# Processed image: 000473.png
# Processed image: 006901.png
# Processed image: 001999.png
# Processed image: 001859.png
# Processed image: 006930.png
# Processed image: 004164.png
# Processed image: 005217.png
# Processed image: 002620.png
# Processed image: 005723.png
# Processed image: 001192.png
# Processed image: 004820.png
# Processed image: 000431.png
# Processed image: 005252.png
# Processed image: 004087.png
# Processed image: 004852.png
# Processed image: 000133.png
# Processed image: 006045.png
# Processed image: 003845.png
# Processed image: 000282.png
# Processed image: 005148.png
# Processed image: 005044.png
# Processed image: 001556.png
# Processed image: 002740.png
# Processed image: 001627.png
# Processed image: 004450.png
# Processed image: 004343.png
# Processed image: 005015.png
# Processed image: 000352.png
# Processed image: 003254.png
# Processed image: 005056.png
# Processed image: 007345.png
# Processed image: 002471.png
# Processed image: 004453.png
# Processed image: 002119.png
# Processed image: 006215.png
# Processed image: 006539.png
# Processed image: 003629.png
# Processed image: 005570.png
# Processed image: 002132.png
# Processed image: 002801.png
# Processed image: 005196.png
# Processed image: 005339.png
# Processed image: 005690.png
# Processed image: 000967.png
# Processed image: 001090.png
# Processed image: 006350.png
# Processed image: 003571.png
# Processed image: 003329.png
# Processed image: 006213.png
# Processed image: 007400.png
# Processed image: 006438.png
# Processed image: 001411.png
# Processed image: 003961.png
# Processed image: 001017.png
# Processed image: 002879.png
# Processed image: 005416.png
# Processed image: 002541.png
# Processed image: 003641.png
# Processed image: 006086.png
# Processed image: 002307.png
# Processed image: 000687.png
# Processed image: 000089.png
# Processed image: 005465.png
# Processed image: 004054.png
# Processed image: 004867.png
# Processed image: 004423.png
# Processed image: 003916.png
# Processed image: 000664.png
# Processed image: 000695.png
# Processed image: 002367.png
# Processed image: 001528.png
# Processed image: 006390.png
# Processed image: 000992.png
# Processed image: 000503.png
# Processed image: 001461.png
# Processed image: 003066.png
# Processed image: 000206.png
# Processed image: 007352.png
# Processed image: 003604.png
# Processed image: 006306.png
# Processed image: 002333.png
# Processed image: 003935.png
# Processed image: 006894.png
# Processed image: 004984.png
# Processed image: 005890.png
# Processed image: 003186.png
# Processed image: 005241.png
# Processed image: 003699.png
# Processed image: 003577.png
# Processed image: 001511.png
# Processed image: 007073.png
# Processed image: 004988.png
# Processed image: 002730.png
# Processed image: 001275.png
# Processed image: 003582.png
# Processed image: 003714.png
# Processed image: 003853.png
# Processed image: 006776.png
# Processed image: 001105.png
# Processed image: 000977.png
# Processed image: 004684.png
# Processed image: 006089.png
# Processed image: 005839.png
# Processed image: 005128.png
# Processed image: 002858.png
# Processed image: 002635.png
# Processed image: 006351.png
# Processed image: 001862.png
# Processed image: 001816.png
# Processed image: 002077.png
# Processed image: 001003.png
# Processed image: 005597.png
# Processed image: 002783.png
# Processed image: 002418.png
# Processed image: 005118.png
# Processed image: 004022.png
# Processed image: 005659.png
# Processed image: 001497.png
# Processed image: 006663.png
# Processed image: 003534.png
# Processed image: 004214.png
# Processed image: 002714.png
# Processed image: 000782.png
# Processed image: 000662.png
# Processed image: 001141.png
# Processed image: 001022.png
# Processed image: 001977.png
# Processed image: 001121.png
# Processed image: 004552.png
# Processed image: 000906.png
# Processed image: 006723.png
# Processed image: 006793.png
# Processed image: 003712.png
# Processed image: 006083.png
# Processed image: 005238.png
# Processed image: 001876.png
# Processed image: 003227.png
# Processed image: 001387.png
# Processed image: 005922.png
# Processed image: 002417.png
# Processed image: 005088.png
# Processed image: 004968.png
# Processed image: 002711.png
# Processed image: 005726.png
# Processed image: 002810.png
# Processed image: 002763.png
# Processed image: 006376.png
# Processed image: 002492.png
# Processed image: 004252.png
# Processed image: 005235.png
# Processed image: 002681.png
# Processed image: 000871.png
# Processed image: 003996.png
# Processed image: 004094.png
# Processed image: 000423.png
# Processed image: 005121.png
# Processed image: 005378.png
# Processed image: 002919.png
# Processed image: 005513.png
# Processed image: 006609.png
# Processed image: 003915.png
# Processed image: 003300.png
# Processed image: 002729.png
# Processed image: 001078.png
# Processed image: 006532.png
# Processed image: 002366.png
# Processed image: 000251.png
# Processed image: 004705.png
# Processed image: 002325.png
# Processed image: 001072.png
# Processed image: 002556.png
# Processed image: 006174.png
# Processed image: 005591.png
# Processed image: 006746.png
# Processed image: 005559.png
# Processed image: 000112.png
# Processed image: 003134.png
# Processed image: 003501.png
# Processed image: 005805.png
# Processed image: 001714.png
# Processed image: 005548.png
# Processed image: 003545.png
# Processed image: 001943.png
# Processed image: 007234.png
# Processed image: 000487.png
# Processed image: 003117.png
# Processed image: 007069.png
# Processed image: 004879.png
# Processed image: 000749.png
# Processed image: 005666.png
# Processed image: 000222.png
# Processed image: 004798.png
# Processed image: 000286.png
# Processed image: 001588.png
# Processed image: 002683.png
# Processed image: 006332.png
# Processed image: 005966.png
# Processed image: 002108.png
# Processed image: 000013.png
# Processed image: 002992.png
# Processed image: 002961.png
# Processed image: 000322.png
# Processed image: 001879.png
# Processed image: 006921.png
# Processed image: 005491.png
# Processed image: 003514.png
# Processed image: 000363.png
# Processed image: 000801.png
# Processed image: 001870.png
# Processed image: 005099.png
# Processed image: 001764.png
# Processed image: 007290.png
# Processed image: 005054.png
# Processed image: 002078.png
# Processed image: 004553.png
# Processed image: 004674.png
# Processed image: 001972.png
# Processed image: 005558.png
# Processed image: 005060.png
# Processed image: 000944.png
# Processed image: 000293.png
# Processed image: 001755.png
# Processed image: 007334.png
# Processed image: 003684.png
# Processed image: 002880.png
# Processed image: 000278.png
# Processed image: 002034.png
# Processed image: 006778.png
# Processed image: 002656.png
# Processed image: 005874.png
# Processed image: 006762.png
# Processed image: 006561.png
# Processed image: 003307.png
# Processed image: 001654.png
# Processed image: 004338.png
# Processed image: 003083.png
# Processed image: 002887.png
# Processed image: 005976.png
# Processed image: 004907.png
# Processed image: 005850.png
# Processed image: 004151.png
# Processed image: 005675.png
# Processed image: 002510.png
# Processed image: 002846.png
# Processed image: 006200.png
# Processed image: 002090.png
# Processed image: 006267.png
# Processed image: 005668.png
# Processed image: 005573.png
# Processed image: 006846.png
# Processed image: 001487.png
# Processed image: 005807.png
# Processed image: 001279.png
# Processed image: 003511.png
# Processed image: 001529.png
# Processed image: 005713.png
# Processed image: 005085.png
# Processed image: 001689.png
# Processed image: 000702.png
# Processed image: 003837.png
# Processed image: 000033.png
# Processed image: 006771.png
# Processed image: 003872.png
# Processed image: 004770.png
# Processed image: 006292.png
# Processed image: 004954.png
# Processed image: 003779.png
# Processed image: 006337.png
# Processed image: 002018.png
# Processed image: 002702.png
# Processed image: 006651.png
# Processed image: 004505.png
# Processed image: 006042.png
# Processed image: 001036.png
# Processed image: 001598.png
# Processed image: 003792.png
# Processed image: 002682.png
# Processed image: 006684.png
# Processed image: 004727.png
# Processed image: 007095.png
# Processed image: 004962.png
# Processed image: 001990.png
# Processed image: 003225.png
# Processed image: 005194.png
# Processed image: 003599.png
# Processed image: 001398.png
# Processed image: 002969.png
# Processed image: 005484.png
# Processed image: 003033.png
# Processed image: 006963.png
# Processed image: 001580.png
# Processed image: 006914.png
# Processed image: 004016.png
# Processed image: 006476.png
# Processed image: 004181.png
# Processed image: 003906.png
# Processed image: 001727.png
# Processed image: 004363.png
# Processed image: 003235.png
# Processed image: 005607.png
# Processed image: 000736.png
# Processed image: 006757.png
# Processed image: 006451.png
# Processed image: 006095.png
# Processed image: 001900.png
# Processed image: 003290.png
# Processed image: 002480.png
# Processed image: 003855.png
# Processed image: 000324.png
# Processed image: 000532.png
# Processed image: 006430.png
# Processed image: 003438.png
# Processed image: 004116.png
# Processed image: 005862.png
# Processed image: 005511.png
# Processed image: 002845.png
# Processed image: 003441.png
# Processed image: 000637.png
# Processed image: 000561.png
# Processed image: 000657.png
# Processed image: 000408.png
# Processed image: 003383.png
# Processed image: 001500.png
# Processed image: 006393.png
# Processed image: 001560.png
# Processed image: 001035.png
# Processed image: 004245.png
# Processed image: 004001.png
# Processed image: 003223.png
# Processed image: 001677.png
# Processed image: 003321.png
# Processed image: 006610.png
# Processed image: 007118.png
# Processed image: 001286.png
# Processed image: 003678.png
# Processed image: 000853.png
# Processed image: 006815.png
# Processed image: 002237.png
# Processed image: 004238.png
# Processed image: 002554.png
# Processed image: 002356.png
# Processed image: 000650.png
# Processed image: 006125.png
# Processed image: 000612.png
# Processed image: 006413.png
# Processed image: 002590.png
# Processed image: 006611.png
# Processed image: 000111.png
# Processed image: 002440.png
# Processed image: 000947.png
# Processed image: 005931.png
# Processed image: 002569.png
# Processed image: 001407.png
# Processed image: 001818.png
# Processed image: 005643.png
# Processed image: 000665.png
# Processed image: 000250.png
# Processed image: 000710.png
# Processed image: 005166.png
# Processed image: 001273.png
# Processed image: 000227.png
# Processed image: 007034.png
# Processed image: 007374.png
# Processed image: 001241.png
# Processed image: 004930.png
# Processed image: 002695.png
# Processed image: 001375.png
# Processed image: 002844.png
# Processed image: 002901.png
# Processed image: 000528.png
# Processed image: 005191.png
# Processed image: 000648.png
# Processed image: 000041.png
# Processed image: 003188.png
# Processed image: 003178.png
# Processed image: 001963.png
# Processed image: 004090.png
# Processed image: 002685.png
# Processed image: 003780.png
# Processed image: 003775.png
# Processed image: 002326.png
# Processed image: 007378.png
# Processed image: 004921.png
# Processed image: 000964.png
# Processed image: 001294.png
# Processed image: 002944.png
# Processed image: 005425.png
# Processed image: 007112.png
# Processed image: 005297.png
# Processed image: 007228.png
# Processed image: 004394.png
# Processed image: 006428.png
# Processed image: 006194.png
# Processed image: 002129.png
# Processed image: 003962.png
# Processed image: 001097.png
# Processed image: 005948.png
# Processed image: 002622.png
# Processed image: 006717.png
# Processed image: 004067.png
# Processed image: 001471.png
# Processed image: 002178.png
# Processed image: 004665.png
# Processed image: 006172.png
# Processed image: 002118.png
# Processed image: 003142.png
# Processed image: 000156.png
# Processed image: 005286.png
# Processed image: 003450.png
# Processed image: 004951.png
# Processed image: 006469.png
# Processed image: 005739.png
# Processed image: 006825.png
# Processed image: 001214.png
# Processed image: 003467.png
# Processed image: 004358.png
# Processed image: 007315.png
# Processed image: 003429.png
# Processed image: 001916.png
# Processed image: 003020.png
# Processed image: 000432.png
# Processed image: 004713.png
# Processed image: 003753.png
# Processed image: 003445.png
# Processed image: 002052.png
# Processed image: 001365.png
# Processed image: 004920.png
# Processed image: 001113.png
# Processed image: 004383.png
# Processed image: 001956.png
# Processed image: 003164.png
# Processed image: 006199.png
# Processed image: 003721.png
# Processed image: 006355.png
# Processed image: 000882.png
# Processed image: 001621.png
# Processed image: 002591.png
# Processed image: 006058.png
# Processed image: 005538.png
# Processed image: 001536.png
# Processed image: 005724.png
# Processed image: 006319.png
# Processed image: 004422.png
# Processed image: 005070.png
# Processed image: 007054.png
# Processed image: 007323.png
# Processed image: 004878.png
# Processed image: 002707.png
# Processed image: 005162.png
# Processed image: 004777.png
# Processed image: 001416.png
# Processed image: 002947.png
# Processed image: 005637.png
# Processed image: 005355.png
# Processed image: 006860.png
# Processed image: 007098.png
# Processed image: 002115.png
# Processed image: 003810.png
# Processed image: 001120.png
# Processed image: 003613.png
# Processed image: 002542.png
# Processed image: 006237.png
# Processed image: 002892.png
# Processed image: 001573.png
# Processed image: 002519.png
# Processed image: 004256.png
# Processed image: 006224.png
# Processed image: 001277.png
# Processed image: 002305.png
# Processed image: 004560.png
# Processed image: 000954.png
# Processed image: 004863.png
# Processed image: 005510.png
# Processed image: 002301.png
# Processed image: 005855.png
# Processed image: 004294.png
# Processed image: 007429.png
# Processed image: 004643.png
# Processed image: 004751.png
# Processed image: 003204.png
# Processed image: 000071.png
# Processed image: 004537.png
# Processed image: 003001.png
# Processed image: 004952.png
# Processed image: 003021.png
# Processed image: 002116.png
# Processed image: 004059.png
# Processed image: 004865.png
# Processed image: 000024.png
# Processed image: 004227.png
# Processed image: 000430.png
# Processed image: 004956.png
# Processed image: 004027.png
# Processed image: 005459.png
# Processed image: 000447.png
# Processed image: 000379.png
# Processed image: 005427.png
# Processed image: 000264.png
# Processed image: 004562.png
# Processed image: 007223.png
# Processed image: 000226.png
# Processed image: 005281.png
# Processed image: 002027.png
# Processed image: 005788.png
# Processed image: 006829.png
# Processed image: 000060.png
# Processed image: 005815.png
# Processed image: 003371.png
# Processed image: 005853.png
# Processed image: 004078.png
# Processed image: 000786.png
# Processed image: 002994.png
# Processed image: 000000.png
# Processed image: 004997.png
# Processed image: 003219.png
# Processed image: 000455.png
# Processed image: 001543.png
# Processed image: 003862.png
# Processed image: 001159.png
# Processed image: 003942.png
# Processed image: 005073.png
# Processed image: 006832.png
# Processed image: 002753.png
# Processed image: 002145.png
# Processed image: 000416.png
# Processed image: 004788.png
# Processed image: 001354.png
# Processed image: 002640.png
# Processed image: 002627.png
# Processed image: 005953.png
# Processed image: 003923.png
# Processed image: 001495.png
# Processed image: 001393.png
# Processed image: 007432.png
# Processed image: 003568.png
# Processed image: 007082.png
# Processed image: 003593.png
# Processed image: 001736.png
# Processed image: 003739.png
# Processed image: 004045.png
# Processed image: 004340.png
# Processed image: 004575.png
# Processed image: 002808.png
# Processed image: 004182.png
# Processed image: 000902.png
# Processed image: 005776.png
# Processed image: 006347.png
# Processed image: 005136.png
# Processed image: 001768.png
# Processed image: 004228.png
# Processed image: 001794.png
# Processed image: 004763.png
# Processed image: 003987.png
# Processed image: 007448.png
# Processed image: 005759.png
# Processed image: 002709.png
# Processed image: 006659.png
# Processed image: 000846.png
# Processed image: 002379.png
# Processed image: 001688.png
# Processed image: 002580.png
# Processed image: 004380.png
# Processed image: 001599.png
# Processed image: 005047.png
# Processed image: 003088.png
# Processed image: 006046.png
# Processed image: 000777.png
# Processed image: 001799.png
# Processed image: 003489.png
# Processed image: 000225.png
# Processed image: 004218.png
# Processed image: 004389.png
# Processed image: 003827.png
# Processed image: 005593.png
# Processed image: 000099.png
# Processed image: 003939.png
# Processed image: 004163.png
# Processed image: 000823.png
# Processed image: 003966.png
# Processed image: 005295.png
# Processed image: 001929.png
# Processed image: 006411.png
# Processed image: 003448.png
# Processed image: 007394.png
# Processed image: 004309.png
# Processed image: 003921.png
# Processed image: 006187.png
# Processed image: 000332.png
# Processed image: 003222.png
# Processed image: 000291.png
# Processed image: 005108.png
# Processed image: 001265.png
# Processed image: 002755.png
# Processed image: 000188.png
# Processed image: 003150.png
# Processed image: 003800.png
# Processed image: 006735.png
# Processed image: 002975.png
# Processed image: 002293.png
# Processed image: 000762.png
# Processed image: 007064.png
# Processed image: 001787.png
# Processed image: 002997.png
# Processed image: 006731.png
# Processed image: 006440.png
# Processed image: 002809.png
# Processed image: 002446.png
# Processed image: 007128.png
# Processed image: 007476.png
# Processed image: 003734.png
# Processed image: 005871.png
# Processed image: 002705.png
# Processed image: 007212.png
# Processed image: 006377.png
# Processed image: 001049.png
# Processed image: 000301.png
# Processed image: 000890.png
# Processed image: 007124.png
# Processed image: 001827.png
# Processed image: 003885.png
# Processed image: 001737.png
# Processed image: 003976.png
# Processed image: 001474.png
# Processed image: 007349.png
# Processed image: 006018.png
# Processed image: 000760.png
# Processed image: 007167.png
# Processed image: 002433.png
# Processed image: 004667.png
# Processed image: 004421.png
# Processed image: 005116.png
# Processed image: 002324.png
# Processed image: 000861.png
# Processed image: 005222.png
# Processed image: 005987.png
# Processed image: 001025.png
# Processed image: 005758.png
# Processed image: 000066.png
# Processed image: 000700.png
# Processed image: 007158.png
# Processed image: 002012.png
# Processed image: 002185.png
# Processed image: 000608.png
# Processed image: 001000.png
# Processed image: 004572.png
# Processed image: 002959.png
# Processed image: 000209.png
# Processed image: 006403.png
# Processed image: 004326.png
# Processed image: 006051.png
# Processed image: 006146.png
# Processed image: 004768.png
# Processed image: 007254.png
# Processed image: 005193.png
# Processed image: 004139.png
# Processed image: 000014.png
# Processed image: 006412.png
# Processed image: 001428.png
# Processed image: 000126.png
# Processed image: 001397.png
# Processed image: 002611.png
# Processed image: 006869.png
# Processed image: 000061.png
# Processed image: 000404.png
# Processed image: 000941.png
# Processed image: 005762.png
# Processed image: 007395.png
# Processed image: 004393.png
# Processed image: 005302.png
# Processed image: 004512.png
# Processed image: 000800.png
# Processed image: 000606.png
# Processed image: 003808.png
# Processed image: 002764.png
# Processed image: 002603.png
# Processed image: 003565.png
# Processed image: 003139.png
# Processed image: 006365.png
# Processed image: 001922.png
# Processed image: 000602.png
# Processed image: 004718.png
# Processed image: 000995.png
# Processed image: 005561.png
# Processed image: 005921.png
# Processed image: 000556.png
# Processed image: 002088.png
# Processed image: 003651.png
# Processed image: 007417.png
# Processed image: 000382.png
# Processed image: 007092.png
# Processed image: 001149.png
# Processed image: 002422.png
# Processed image: 000362.png
# Processed image: 002577.png
# Processed image: 004844.png
# Processed image: 004754.png
# Processed image: 004744.png
# Processed image: 001978.png
# Processed image: 000813.png
# Processed image: 007398.png
# Processed image: 005127.png
# Processed image: 002279.png
# Processed image: 001420.png
# Processed image: 002929.png
# Processed image: 003693.png
# Processed image: 001824.png
# Processed image: 001419.png
# Processed image: 002124.png
# Processed image: 000415.png
# Processed image: 003623.png
# Processed image: 005518.png
# Processed image: 005187.png
# Processed image: 001062.png
# Processed image: 002407.png
# Processed image: 005169.png
# Processed image: 005742.png
# Processed image: 006549.png
# Processed image: 001346.png
# Processed image: 002477.png
# Processed image: 003503.png
# Processed image: 003462.png
# Processed image: 006340.png

# %%
def read_image2(image_name):
    image_path = os.path.join(output_dir, f"{image_name}.png") 
    image = cv2.imread(image_path)

    if image is None:
        raise FileNotFoundError(f"Not Found: {image_path}")

    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    print(f"Image shape: {image.shape}")
    return image

# %%
import matplotlib.pyplot as plt
image = read_image2("000007")
plt.imshow(image)
plt.axis("off")
plt.show()

# %% [markdown]
# # normalizes pixel values, and saves them as .npy files in the output directory in range from 0 to 1
# we will perform this code after data augmentation

# %%
# import cv2
# import numpy as np
# import os

# dataset_path = "/"
# output_path = ""

# if not os.path.exists(output_path):
#     os.makedirs(output_path)

# for filename in os.listdir(dataset_path):
#     if filename.endswith('.png') or filename.endswith('.jpg'):
#         image_path = os.path.join(dataset_path, filename)
#         image = cv2.imread(image_path)
#         image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
#         normalized_image = image.astype(np.float32) / 255.0
        
#         save_path = os.path.join(output_path, filename.split('.')[0] + ".npy")
#         np.save(save_path, normalized_image)

# %%
# normalized_image = np.load("path/to/normalized_images/your_image_name.npy")
